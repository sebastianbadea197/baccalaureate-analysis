# %%
import pandas as pd
import numpy as np
import helper

# %%
def roman_to_int(number):
    """
    Convert Roman numeral to integer.
    
    Parameters:
    - number (str): The Roman numeral to convert.
    
    Returns:
    - int: The converted integer.
    """
    roman_dict = {
        'I': 1,
        'V': 5,
        'X': 10,
        'L': 50,
        'C': 100,
        'D': 500,
        'M': 1000
    }
    
    total = 0
    prev_value = 0
    
    for char in number:
        value = roman_dict[char]
        if value > prev_value:
            # If the current numeral is larger than the previous one, 
            # subtract twice the value of the previous numeral (because we added it once already)
            total += value - 2 * prev_value
        else:
            total += value
        prev_value = value
        
    return total

def translate_columns(df):
    """
    Translates specified columns in a DataFrame based on a pre-defined translation mapping.
    
    Parameters:
    - df (pd.DataFrame): The DataFrame to modify.
    - column_names (dict): Dictionary mapping old column names to new column names.
    
    Returns:
    - pd.DataFrame: The modified DataFrame.
    """
    df_copy = df.copy()
    # Pre-defined translation mapping
    translation_mapping = {
        'specialization': {
            'Tehnician în automatizări': 'Automation Technician',
            'Științe Sociale': 'Social Sciences',
            'Tehnician în turism': 'Tourism Technician'
        },
        'profile': {
            'Tehnic': 'Technical',
            'Uman': 'Humanities',
            'Servicii': 'Services'
        },
        'class_type': {
            'Tehnologică': 'Technological',
            'Teoretică': 'Theoretical',
            'Vocațională': 'Vocational'
        },
        'school_type': {
            'Zi': 'Daytime',
            'Frecvență redusă': 'Reduced Frequency',
            'Seral': 'Evening'
        }
    }
    
    for col, mapping in translation_mapping.items():
        for key, value in mapping.items():
            df_copy.loc[df_copy[col] == key, col] = value
    
    return df_copy

# %% [markdown]
# ## 2023

# %%
# read 2023.xlsx as a pandas dataframe
elevi = pd.read_excel('../data/2023/2023.xlsx')
scoli = pd.read_excel("../data/general/scoli.xlsx")

# %%
elevi.head()
# Out:
#    Cod unic candidat Sex               Specializare    Profil      Fileira  \
# 0              10005   M  Tehnician în automatizări    Tehnic  Tehnologică
# 1              12037   M            Științe Sociale      Uman    Teoretică
# 2              12284   M        Tehnician în turism  Servicii  Tehnologică
# 3              12865   F                  Filologie      Uman    Teoretică
# 4              12923   F     Organizator banqueting  Servicii  Tehnologică
#
#   Forma de învățământ Mediu candidat  Unitate (SIIIR)  Unitate (SIRUES)  \
# 0                  Zi          URBAN       3261101959       320960511.0
# 1    Frecvență redusă          URBAN       3661100016          718401.0
# 2                  Zi          URBAN       1161104376          424268.0
# 3                  Zi          URBAN        961100082          404517.0
# 4                  Zi          RURAL       2461103282         1182013.0
#
#                Clasa  ... NOTA_CONTESTATIE_EA CONTESTATIE_EB  \
# 0          a XII-a R  ...                 NaN             Nu
# 1         a XIII-a A  ...                 NaN             Nu
# 2          a XII-a B  ...                 NaN             Nu
# 3  a XII-a a XII-a B  ...                 NaN             Nu
# 4         a XIII-a R  ...                 NaN             Nu
#
#   NOTA_CONTESTATIE_EB CONTESTATIE_EC NOTA_CONTESTATIE_EC CONTESTATIE_ED  \
# 0                 NaN             Nu                 NaN             Da
# 1                 NaN             Nu                 NaN             Nu
# 2                 NaN             Nu                 NaN             Nu
# 3                 NaN             Nu                 NaN             Nu
# 4                 NaN             Nu                 NaN             Nu
#
#   NOTA_CONTESTATIE_ED PUNCTAJ DIGITALE      STATUS Medie
# 0                4.45             41.0  Nepromovat   NaN
# 1                 NaN             13.0    Promovat  6.20
# 2                 NaN             34.0    Promovat  6.35
# 3                 NaN             19.0  Nepromovat  5.48
# 4                 NaN              NaN    Promovat  6.26
#
# [5 rows x 52 columns]

# %%
elevi["Clasa"] = elevi["Clasa"].apply(lambda x: x.split()[1])
elevi['Clasa'] = elevi['Clasa'].str[:-2]
elevi['Clasa'] = elevi['Clasa'].apply(helper.roman_to_int)
elevi.head()
# Out:
#    Cod unic candidat Sex               Specializare    Profil      Fileira  \
# 0              10005   M  Tehnician în automatizări    Tehnic  Tehnologică
# 1              12037   M            Științe Sociale      Uman    Teoretică
# 2              12284   M        Tehnician în turism  Servicii  Tehnologică
# 3              12865   F                  Filologie      Uman    Teoretică
# 4              12923   F     Organizator banqueting  Servicii  Tehnologică
#
#   Forma de învățământ Mediu candidat  Unitate (SIIIR)  Unitate (SIRUES)  \
# 0                  Zi          URBAN       3261101959       320960511.0
# 1    Frecvență redusă          URBAN       3661100016          718401.0
# 2                  Zi          URBAN       1161104376          424268.0
# 3                  Zi          URBAN        961100082          404517.0
# 4                  Zi          RURAL       2461103282         1182013.0
#
#    Clasa  ... NOTA_CONTESTATIE_EA CONTESTATIE_EB NOTA_CONTESTATIE_EB  \
# 0     12  ...                 NaN             Nu                 NaN
# 1     13  ...                 NaN             Nu                 NaN
# 2     12  ...                 NaN             Nu                 NaN
# 3     12  ...                 NaN             Nu                 NaN
# 4     13  ...                 NaN             Nu                 NaN
#
#   CONTESTATIE_EC NOTA_CONTESTATIE_EC CONTESTATIE_ED NOTA_CONTESTATIE_ED  \
# 0             Nu                 NaN             Da                4.45
# 1             Nu                 NaN             Nu                 NaN
# 2             Nu                 NaN             Nu                 NaN
# 3             Nu                 NaN             Nu                 NaN
# 4             Nu                 NaN             Nu                 NaN
#
#   PUNCTAJ DIGITALE      STATUS Medie
# 0             41.0  Nepromovat   NaN
# 1             13.0    Promovat  6.20
# 2             34.0    Promovat  6.35
# 3             19.0  Nepromovat  5.48
# 4              NaN    Promovat  6.26
#
# [5 rows x 52 columns]

# %%
elevi.head()
# Out:
#    Cod unic candidat Sex               Specializare    Profil      Fileira  \
# 0              10005   M  Tehnician în automatizări    Tehnic  Tehnologică
# 1              12037   M            Științe Sociale      Uman    Teoretică
# 2              12284   M        Tehnician în turism  Servicii  Tehnologică
# 3              12865   F                  Filologie      Uman    Teoretică
# 4              12923   F     Organizator banqueting  Servicii  Tehnologică
#
#   Forma de învățământ Mediu candidat  Unitate (SIIIR)  Unitate (SIRUES)  \
# 0                  Zi          URBAN       3261101959       320960511.0
# 1    Frecvență redusă          URBAN       3661100016          718401.0
# 2                  Zi          URBAN       1161104376          424268.0
# 3                  Zi          URBAN        961100082          404517.0
# 4                  Zi          RURAL       2461103282         1182013.0
#
#    Clasa  ... NOTA_CONTESTATIE_EA CONTESTATIE_EB NOTA_CONTESTATIE_EB  \
# 0     12  ...                 NaN             Nu                 NaN
# 1     13  ...                 NaN             Nu                 NaN
# 2     12  ...                 NaN             Nu                 NaN
# 3     12  ...                 NaN             Nu                 NaN
# 4     13  ...                 NaN             Nu                 NaN
#
#   CONTESTATIE_EC NOTA_CONTESTATIE_EC CONTESTATIE_ED NOTA_CONTESTATIE_ED  \
# 0             Nu                 NaN             Da                4.45
# 1             Nu                 NaN             Nu                 NaN
# 2             Nu                 NaN             Nu                 NaN
# 3             Nu                 NaN             Nu                 NaN
# 4             Nu                 NaN             Nu                 NaN
#
#   PUNCTAJ DIGITALE      STATUS Medie
# 0             41.0  Nepromovat   NaN
# 1             13.0    Promovat  6.20
# 2             34.0    Promovat  6.35
# 3             19.0  Nepromovat  5.48
# 4              NaN    Promovat  6.26
#
# [5 rows x 52 columns]

# %%
# from the "Medie" column from the "data" dataframe, change the "NaN" values with 0
elevi["Medie"].fillna(0, inplace=True)

# %%
elevi.loc[elevi['NOTA_CONTESTATIE_EA'].notnull(), 'NOTA_EA'] = elevi['NOTA_CONTESTATIE_EA']
elevi.loc[elevi['NOTA_CONTESTATIE_EB'].notnull(), 'NOTA_EB'] = elevi['NOTA_CONTESTATIE_EB']
elevi.loc[elevi['NOTA_CONTESTATIE_EC'].notnull(), 'NOTA_EC'] = elevi['NOTA_CONTESTATIE_EC']
elevi.loc[elevi['NOTA_CONTESTATIE_ED'].notnull(), 'NOTA_ED'] = elevi['NOTA_CONTESTATIE_ED']

# %%
selected_columns = ['Cod unic candidat','Unitate (SIIIR)','Sex', 'Specializare', 'Profil', 'Fileira','Forma de învățământ', 'Mediu candidat', 'Clasa', 'NOTA_EA','NOTA_EB', 'NOTA_EC', 'NOTA_ED', 'STATUS', 'Medie']
selected_dataframe = elevi[selected_columns]

new_column_names = {
    'Cod unic candidat': 'id',
    'Unitate (SIIIR)': 'school_id',
    'Sex': 'gender',
    'Specializare': 'specialization',
    'Profil': 'profile',
    'Fileira': 'class_type',
    'Forma de învățământ': 'school_type',
    'Mediu candidat': 'location_type',
    'Clasa': 'class',
    'NOTA_EA': 'mark_a',
    'NOTA_EB': 'mark_b',
    'NOTA_EC': 'mark_c',
    'NOTA_ED': 'mark_d',
    'STATUS': 'pass',
    'Medie': 'final_mark'
}
selected_dataframe.rename(columns=new_column_names, inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8204\3504542537.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_dataframe.rename(columns=new_column_names, inplace=True)

# %%
selected_dataframe['pass'] = selected_dataframe['pass'].apply(lambda x: 1 if x == 'Promovat' else 0)

# %%
selected_dataframe_translated = translate_columns(selected_dataframe)

# %%
selected_dataframe_translated
# Out:
#              id   school_id genre                     specialization  \
# 0         10005  3261101959     M              Automation Technician
# 1         12037  3661100016     M                    Social Sciences
# 2         12284  1161104376     M                 Tourism Technician
# 3         12865   961100082     F                          Filologie
# 4         12923  2461103282     F             Organizator banqueting
# ...         ...         ...   ...                                ...
# 130517  1428699  3661100554     F                             Muzica
# 130518  1428838  1761101468     F  Tehnician în activități de comerț
# 130519  1428841  1761101468     M  Tehnician în activități de comerț
# 130520  1428971  1761101206     M           Liceu cu program sportiv
# 130521  1428972  1761101206     M           Liceu cu program sportiv
#
#                          profile     class_type        school_type  \
# 0                      Technical  Technological            Daytime
# 1                     Humanities    Theoretical  Reduced Frequency
# 2                       Services  Technological            Daytime
# 3                     Humanities    Theoretical            Daytime
# 4                       Services  Technological            Daytime
# ...                          ...            ...                ...
# 130517                  Artistic     Vocational            Daytime
# 130518                  Services  Technological            Daytime
# 130519                  Services  Technological            Daytime
# 130520  Educație fizică și sport     Vocational            Daytime
# 130521  Educație fizică și sport     Vocational            Daytime
#
#        location_type  class  mark_a  mark_b  mark_c  mark_d  pass  final_mark
# 0              URBAN     12    5.35     NaN    5.80    4.45     0        0.00
# 1              URBAN     13    7.40     NaN    6.05    5.15     1        6.20
# 2              URBAN     12    5.50     NaN    8.50    5.05     1        6.35
# 3              URBAN     12    5.20     NaN    5.15    6.10     0        5.48
# 4              RURAL     13    5.00     NaN    5.80    8.00     1        6.26
# ...              ...    ...     ...     ...     ...     ...   ...         ...
# 130517         URBAN     12    6.60     NaN    5.70    6.50     1        6.26
# 130518         RURAL     12    3.10     NaN    1.45    3.80     0        0.00
# 130519         RURAL     12    7.65     NaN    7.55    8.35     1        7.85
# 130520         URBAN     12    5.00     NaN    6.30    5.65     0        5.65
# 130521         URBAN     12    3.60     NaN    2.70    2.80     0        0.00
#
# [130522 rows x 15 columns]

# %%
selected_dataframe_translated.to_excel('elevi.xlsx', index=False)
selected_dataframe_translated.to_csv("elevi.csv", index=False)

# %% [markdown]
# ## 2022

# %%
# read 2023.xlsx as a pandas dataframe
elevi = pd.read_excel('../data/2022/2022.xlsx')

# %%
elevi.to_csv("elevi.csv", index=False)

# %%
elevi.loc[elevi['NOTA_CONTESTATIE_EA'].notnull(), 'NOTA_EA'] = elevi['NOTA_CONTESTATIE_EA']
elevi.loc[elevi['NOTA_CONTESTATIE_EB'].notnull(), 'NOTA_EB'] = elevi['NOTA_CONTESTATIE_EB']
elevi.loc[elevi['NOTA_CONTESTATIE_EC'].notnull(), 'NOTA_EC'] = elevi['NOTA_CONTESTATIE_EC']
elevi.loc[elevi['NOTA_CONTESTATIE_ED'].notnull(), 'NOTA_ED'] = elevi['NOTA_CONTESTATIE_ED']

# %%
selected_columns = ['Cod','Cod SIIIR','SEX', 'SPECIALIZARE', 'PROFIL', 'FILIERA','FORMA_DE_INV', 'MEDIU', 'CLASA', 'NOTA_EA','NOTA_EB', 'NOTA_EC', 'NOTA_ED', 'STATUS_FINAL', 'MEDIA_FINALA']
selected_dataframe = elevi[selected_columns]

new_column_names = {
    'Cod': 'id',
    'Cod SIIIR': 'school_id',
    'SEX': 'gender',
    'SPECIALIZARE': 'specialization',
    'PROFIL': 'profile',
    'FILIERA': 'class_type',
    'FORMA_DE_INV': 'school_type',
    'MEDIU': 'location_type',
    'CLASA': 'class',
    'NOTA_EA': 'mark_a',
    'NOTA_EB': 'mark_b',
    'NOTA_EC': 'mark_c',
    'NOTA_ED': 'mark_d',
    'STATUS_FINAL': 'pass',
    'MEDIA_FINALA': 'final_mark'
}
selected_dataframe.rename(columns=new_column_names, inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8204\509315111.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_dataframe.rename(columns=new_column_names, inplace=True)

# %%
selected_dataframe_translated = translate_columns(selected_dataframe)

# %%
selected_dataframe_translated.to_csv("../data/2022/elevi.csv", index=False)
selected_dataframe_translated.to_excel("../data/2022/elevi.xlsx", index=False)

# %% [markdown]
# ## 2021

# %%
elevi = pd.read_excel('../data/2021/2021.xlsx')

elevi.to_csv("../data/2021/elevi.csv", index=False)

# %% [markdown]
# ## Scrapbook

# %%
scoli.head()
# Out:
#          Cod                  Judet                     Statut  \
# 0  261205195   ARAD County, Romania  Cu personalitate juridică
# 1  261205453   ARAD County, Romania  Cu personalitate juridică
# 2  361204107  ARGEŞ County, Romania  Cu personalitate juridică
# 3  261205236   ARAD County, Romania  Cu personalitate juridică
# 4  461208824  BACĂU County, Romania  Cu personalitate juridică
#
#              Tip_unitate      Tip
# 0  Unitate de învățământ  Privată
# 1  Unitate de învățământ  Privată
# 2  Unitate de învățământ  Privată
# 3  Unitate de învățământ  Privată
# 4  Unitate de învățământ  Privată

# %%
scoli.columns
# Out:
# Index(['Cod', 'Judet', 'Statut', 'Tip_unitate', 'Tip'], dtype='object')

# %%
scoli['Statut'].unique()
# Out:
# array(['Cu personalitate juridică', 'Arondată'], dtype=object)
